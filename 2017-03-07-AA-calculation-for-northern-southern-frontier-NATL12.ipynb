# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import cartopy.feature as cfeature

# %%
# %matplotlib inline
import xarray as xr

file1="/media/extra/DATA/NATL12/NATL12_bathymetry_28S_80N.nc"
file2="/media/extra/DATA/NATL12/NATL12_bathymetry_20S_80N.nc"
file3="/media/extra/DATA/NATL12/NATL12_bathymetry_28S_70N.nc"
file4="/media/extra/DATA/NATL12/NATL12_bathymetry_20S_70N.nc"

ds1=xr.open_dataset(file1)
ds2=xr.open_dataset(file2)
ds3=xr.open_dataset(file3)
ds4=xr.open_dataset(file4)

bathy1=ds1.Bathymetry
bathy2=ds2.Bathymetry
bathy3=ds3.Bathymetry
bathy4=ds4.Bathymetry

lat1=ds1.nav_lat
lon1=ds1.nav_lon
lat2=ds2.nav_lat
lon2=ds2.nav_lon
lat3=ds3.nav_lat
lon3=ds3.nav_lon
lat4=ds4.nav_lat
lon4=ds4.nav_lon

import numpy as npy
bathy1_ma=bathy1.where(bathy1>0)
tot1=npy.count_nonzero(npy.nan_to_num(bathy1))
tot2=npy.count_nonzero(npy.nan_to_num(bathy2))
tot3=npy.count_nonzero(npy.nan_to_num(bathy3))
tot4=npy.count_nonzero(npy.nan_to_num(bathy4))
print "tot1 = ",tot1
print "tot2 = ",tot2
print "tot3 = ",tot3
print "tot4 = ",tot4
# Out:
# /home/albert/anaconda2/lib/python2.7/site-packages/xarray/core/variable.py:1130: RuntimeWarning: invalid value encountered in greater
#   if not reflexive
# tot1 =  1207853
# tot2 =  1134598
# tot3 =  1074824
# tot4 =  1001569

# %%
# %matplotlib inline
import xarray as xr

file1="/media/extra/DATA/NATL12/NATL12ext_bathymetry_v4.0.nc"
file2="/media/extra/DATA/NATL12/NATL12ext_bathymetry_v5.0.nc"
ds1=xr.open_dataset(file1)
ds2=xr.open_dataset(file2)

bathy1=ds1.Bathymetry
bathy2=ds2.Bathymetry

import numpy as npy
tot1=npy.count_nonzero(npy.nan_to_num(bathy1))
tot2=npy.count_nonzero(npy.nan_to_num(bathy2))
print "tot1 = ",tot1
print "tot2 = ",tot2
# Out:
# tot1 =  1226512
# tot2 =  1207853

# %%
lat1.shape
# Out:
# (1672, 1609)

# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import cartopy.feature as cfeature

fig = plt.figure(figsize=(20,15))

ax1 = fig.add_subplot(221,projection=ccrs.PlateCarree(central_longitude=-30))
ax1.set_extent([-110, 58, -7, 85])
cmap = plt.cm.jet
cmap.set_under(color='grey')
pcolor=ax1.pcolormesh(lon1,lat1,npy.nan_to_num(bathy1),transform=ccrs.PlateCarree(),cmap=cmap,vmin=15,vmax=8000)
ax1.add_feature(cfeature.LAND,facecolor='grey')
ax1.coastlines()
ax1.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=2, color='gray', alpha=0.5, linestyle='--')

ax2 = fig.add_subplot(222,projection=ccrs.PlateCarree(central_longitude=-30))
ax2.set_extent([-110, 58, -7, 85])
cmap = plt.cm.jet
cmap.set_under(color='grey')
pcolor=ax2.pcolormesh(lon2,lat2,npy.nan_to_num(bathy2),transform=ccrs.PlateCarree(),cmap=cmap,vmin=15,vmax=8000)
ax2.add_feature(cfeature.LAND,facecolor='grey')
ax2.coastlines()
ax2.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=2, color='gray', alpha=0.5, linestyle='--')

ax3 = fig.add_subplot(223,projection=ccrs.PlateCarree(central_longitude=-30))
ax3.set_extent([-110, 58, -7, 85])
cmap = plt.cm.jet
cmap.set_under(color='grey')
pcolor=ax3.pcolormesh(lon3,lat3,npy.nan_to_num(bathy3),transform=ccrs.PlateCarree(),cmap=cmap,vmin=15,vmax=8000)
ax3.add_feature(cfeature.LAND,facecolor='grey')
ax3.coastlines()
ax3.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=2, color='gray', alpha=0.5, linestyle='--')

ax4 = fig.add_subplot(224,projection=ccrs.PlateCarree(central_longitude=-30))
ax4.set_extent([-110, 58, -7, 85])
cmap = plt.cm.jet
cmap.set_under(color='grey')
pcolor=ax4.pcolormesh(lon4,lat4,npy.nan_to_num(bathy4),transform=ccrs.PlateCarree(),cmap=cmap,vmin=15,vmax=8000)
ax4.add_feature(cfeature.LAND,facecolor='grey')
ax4.coastlines()
ax4.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=2, color='gray', alpha=0.5, linestyle='--')


fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.03, 0.7])
cbar=fig.colorbar(pcolor, cax=cbar_ax)
cbar.ax.tick_params(labelsize=20)
cbar.set_label("depth in m",size=17)

fig.suptitle("NATL12 bathymetry", fontsize=25)

plt.savefig("bathys_all_natl12.png")

# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import cartopy.feature as cfeature

fig = plt.figure(figsize=(20,15))

ax1 = fig.add_subplot(111,projection=ccrs.PlateCarree(central_longitude=-30))
ax1.set_extent([-110, 58, -7, 85])
cmap = plt.cm.jet
cmap.set_under(color='grey')
pcolor=ax1.pcolormesh(lon2,lat2,npy.nan_to_num(bathy2),transform=ccrs.PlateCarree(),cmap=cmap,vmin=15,vmax=8000)
ax1.add_feature(cfeature.LAND,facecolor='grey')
ax1.coastlines()
ax1.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=2, color='gray', alpha=0.5, linestyle='--')

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.03, 0.7])
cbar=fig.colorbar(pcolor, cax=cbar_ax)
cbar.ax.tick_params(labelsize=20)
cbar.set_label("depth in m",size=17)

fig.suptitle("NACHOS12 bathymetry", fontsize=25)

plt.savefig("bathys_nachos12.png")
