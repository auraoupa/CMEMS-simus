# %%
import sys
import numpy as np
import numpy.ma as ma
import xarray as xr
import matplotlib.pyplot as plt
sys.path.insert(0,'/home/albert7a/lib/python/cartopy/lib/cartopy')
import matplotlib.ticker as mticker
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.feature as cfeature
import cmocean

# %matplotlib inline
# Out:
# /home/albert/anaconda2/lib/python2.7/site-packages/matplotlib/ticker.py:1685: UserWarning: Steps argument should be a sequence of numbers
# increasing from 1 to 10, inclusive. Behavior with
# values outside this range is undefined, and will
# raise a ValueError in future versions of mpl.
#   warnings.warn('Steps argument should be a sequence of numbers\n'

# %%
case='MAA13'

dirmean='/media/extra/DATA/NACHOS12.L75/NACHOS12.L75-'+case+'-S/'

fileSSH=dirmean+'NACHOS12.L75-MAA13.1d_sshmean.nc'

dsT=xr.open_dataset(fileSSH)
ssh=dsT.mean_sossheig

# %%
fig=plt.figure(figsize=(13,7))
ssh.plot()
plt.title('NACHOS12.L75-MAA13 SSH mean')
plt.savefig('/media/extra/DATA/NACHOS12.L75/NACHOS12.L75-MAA13-PLOTS/NACHOS12.L75-MAA13-SSHmean-2010-2013.png')
