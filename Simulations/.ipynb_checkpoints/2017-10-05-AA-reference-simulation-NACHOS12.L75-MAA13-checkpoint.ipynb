# %% [markdown]
# # Reference simulation NACHOS12.L75-MAA13
#
# The NACHOS12.L75 configuration originates from Romains' ORCA12 and Jean-Marc's EORCA12 and eORCA12 configuration.
#
# The grid is 1609x1568x75, 103.6°W-57.5°E x 19.2°S-81.2°N.
#
# ## CPP.keys and namelists
#
# - rev 7046 trunk NEMO (4.0)
# - [install.history](https://github.com/auraoupa/CONFIGS/blob/master/CONFIG_NACHOS12.L75/NACHOS12.L75-MAA13/install_history)
# - [CPP.keys](https://github.com/auraoupa/CONFIGS/blob/master/CONFIG_NACHOS12.L75/NACHOS12.L75-MAA13/CPP.keys)
# - [namelist](https://github.com/auraoupa/RUNS/blob/master/RUN_NACHOS12.L75/NACHOS12.L75-MAA13/CTL/namelist.NACHOS12.L75-MAA13)
# - [namelist_ice](https://github.com/auraoupa/RUNS/blob/master/RUN_NACHOS12.L75/NACHOS12.L75-MAA13/CTL/namelist_ice)
# - [domain_def.xml](),[field_def.xml](),[file_def.xml](),[grid_def.xml](), [iodef.xml]()
#
#
# ## Configuration files
#
# ### Coordinates
#
# - NACHOS12.L75_coordinates_20S_80N_v2.0.nc
#
# From JMM's eORCA12_coordinates.nc, ncks -F -d x,2271,3879 -d y,1807,3374.
#
#
# ### Bathymetry
#
# - NACHOS12.L75_bathymetry_20S_80N_nfrontiercleaned_repeat3glorys_retouchbalt.nc
#
# From RBB's eORCA12_bathymetry_v2.4.nc, ncks -F -d x,2271,3879 -d y,1807,3374. Then, with BMGTools, filling the lakes, Red Sea, Black Sea, Pacific and Indian corners, Hudson Bay, Baltic Sea, Northern Greenland Fjords (crossed by the frontier). With personnal tool, ORCA025 bathymetry at the frontier, repeated for 3 levels.
#
# ## Atmospheric forcing files
#
# - DFS5.2 forcing files : drowned_(u10/v10/radsw/radlw/t2/q2/precip/snow)_DFS5.2_y????.nc
#
# Associated weight files :
#
# - wght_DFS5_NACHOS12.L75_bicub.nc and wght_DFS5_NACHOS12.L75_bilin.nc
#
# From JMM's wght_DFS5_eORCA12_bicub.nc and wght_DFS5_eORCA12_bilin.nc, ncks -F -d x,2271,3879 -d y,1807,3374.
#
# ## Boundary conditions : BDY for northern and southern frontier
#
# - new-GLORYS2V4-NACHOS12.L75_(S/N)bdy(SSH/U/V/T/S)_y????.nc
#
# From GLORYS2V4 monthly files, with personnal tool, slice the northern and southern frontier, repeat each colum 3 times et cut appropriately.
#
# ## Initial conditions
#
# - vertext_clean_drowned_GLORYS2V4_NACHOS025_gridT_y2010.nc
# - vertext_clean_drowned_GLORYS2V4_NACHOS025_gridS_y2010.nc
#
# From GLORYS2V4 2010 monthly files, drown onto land and vertical extent.
# Associated weight file :
#
# - wght_bilinear_NACHOS12_pseudo_coord.nc
#
# Created from scratch with NEMO Tool WEIGHTS with pseudo-coordinates for NARYS and NACHOS12.
#
# ## Damping files
#
# - vertext_clean_drowned_GLORYS2V4_NACHOS025_gridT_y????.nc
# - vertext_clean_drowned_GLORYS2V4_NACHOS025_gridS_y????.nc
#
# Same as initial conditions, for every year needed.
#
# ## Sea surface restoring
#
# - vertext_clean_drowned_GLORYS2V4_NACHOS025_SSS_nodepth_y????.nc
#
# Surface slice of damping files.
# Associated weight file :
#
# - wght_bilinear_NACHOS12_pseudo_coord_2D.nc
#
# Linked to wght_bilinear_NACHOS12_pseudo_coord.nc
#
# ## Other files
#
# ### Penetrative solar radiation
#
# - chlaseawifs_c1m-99-05_smooth_NACHOS12.nc
#
# From JMM's chlaseawifs_c1m-99-05_smooth_ORCA_R12.nc, ncks -d XAXIS,2271,3879 -d YAXIS,1260,2827.
#
# ### Run-offs
#
# - NACHOS12.L75_runoff_v2.4.nc
#
# From JMM's eORCA12_runoff_v2.4.nc, ncks -O -F -d x,2271,3879 -d y,1807,3374.
